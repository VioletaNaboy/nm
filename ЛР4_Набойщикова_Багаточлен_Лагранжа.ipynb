# %% [markdown]
# <a href="https://colab.research.google.com/github/VioletaNaboy/nm/blob/main/%D0%9B%D0%A04_%D0%9D%D0%B0%D0%B1%D0%BE%D0%B9%D1%89%D0%B8%D0%BA%D0%BE%D0%B2%D0%B0_%D0%91%D0%B0%D0%B3%D0%B0%D1%82%D0%BE%D1%87%D0%BB%D0%B5%D0%BD_%D0%9B%D0%B0%D0%B3%D1%80%D0%B0%D0%BD%D0%B6%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Лабораторна Робота 4
# #студентки групи 3-3з
# #Набойщикової Віолети
# #Варіант 10
# Багаточлен Лагранжа

# %% [markdown]
# #Завдання: Побудувати інтерполяційний багаточлен Лагранжа функції f(x), що задана таблицею:
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, expand
x=np.array([-1.,0.,1.,5.], dtype=float)
y=np.array([11.,4.,7.,-1.], dtype=float)
x1 = -0.5 # точка, в якій потрібно обчислити значення
x2 = 2
x3 = 3
x4 = 4.5
def lagrange_interpolation(x, y, x_test):
    n = len(x)
    p = np.zeros(n) # масив для зберігання значень багаточленів L_i
    for i in range(n):
        # обчислюємо багаточлен L_i, який складається з n членів
        # кожен член дорівівнює добутку (x-x_j)/(x_i-x_j) для j=0..n, j!=i
        p_i = 1
        for j in range(n):
            if i != j:
                p_i *= (x_test - x[j])/(x[i] - x[j])
        p[i] = p_i
    return np.dot(y, p) # повертаємо значення багаточлена
# обчислюємо інтерполяційний багаточлен та його значення у точці x_test
f1 = lagrange_interpolation(x, y, x1)
print("Значення функції у точці x_1 =", f1.round(4))
f2 = lagrange_interpolation(x, y, x2)
print("Значення функції у точці x_2 =", f2.round(4))
f3 = lagrange_interpolation(x, y, x3)
print("Значення функції у точці x_3 =", f3.round(4))
f4 = lagrange_interpolation(x, y, x4)
print("Значення функції у точці x_4 =", f4.round(4))
# Out:
# Значення функції у точці x_1 = 5.875
# Значення функції у точці x_2 = 14.0
# Значення функції у точці x_3 = 19.0
# Значення функції у точці x_4 = 9.625

# %%
xnew=np.linspace(np.min(x),np.max(x),100) #точки, за якими будуємо графік
ynew=[lagrange_interpolation(x,y,i) for i in xnew]
plt.plot(x,y,'o',xnew,ynew) #будуємо графік функції Лагранжа
plt.plot(x1,f1,'ro')
plt.plot(x2,f2,'ro')
plt.plot(x3,f3,'ro')
plt.plot(x4,f4,'ro')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Lagrange Polynomial_1')
plt.grid(True)
plt.show()

# %%
from scipy.interpolate import lagrange
#Перевірка
f = lagrange(x, y)
fig = plt.figure(figsize = (7,5))
plt.plot(xnew, f(xnew), 'b', x, y, 'ro')
plt.title('Lagrange Polynomial_2')
plt.plot(x1,f1,'o')
plt.plot(x2,f2,'o')
plt.plot(x3,f3,'o')
plt.plot(x4,f4,'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
